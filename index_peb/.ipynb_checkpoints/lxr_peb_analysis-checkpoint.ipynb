# %%
import sys
sys.path.append('/Users/i335644/PycharmProjects/my_inv_mgr/')
import pandas as pd
import utility

# %%
index_code = '000905'

# %%
file_path = data_path = '%s/index_peb/%s_peb.csv' % (
            utility.DATA_ROOT, utility.convert_code_2_csvfilename(index_code))
df = pd.read_csv(file_path)

# %% [markdown]
# ## PE走势

# %%
df_pe = df[['date', 'pe_ttm_avg', 'pe_ttm_ew', 'pe_ttm_ewpvo', 'pe_ttm_mcw', 'pe_ttm_median']]
df_pe
# Out:
#                            date  pe_ttm_avg  pe_ttm_ew  pe_ttm_ewpvo  \
# 0     2007-01-15T00:00:00+08:00   52.739173  55.414621     37.305993
# 1     2007-01-16T00:00:00+08:00   53.265497  57.399322     38.477138
# 2     2007-01-17T00:00:00+08:00   54.356996  56.438034     37.987824
# 3     2007-01-18T00:00:00+08:00   55.935886  57.575062     38.883958
# 4     2007-01-19T00:00:00+08:00   57.413885  59.927825     40.290736
# ...                         ...         ...        ...           ...
# 3378  2020-12-03T00:00:00+08:00   39.987767  31.817699     21.555509
# 3379  2020-12-04T00:00:00+08:00   40.256163  31.882964     21.533901
# 3380  2020-12-07T00:00:00+08:00   39.978556  31.638667     21.308318
# 3381  2020-12-08T00:00:00+08:00   39.996667  31.502376     21.242057
# 3382  2020-12-09T00:00:00+08:00   39.261788  30.945782     20.900294
#
#       pe_ttm_mcw  pe_ttm_median
# 0      50.439293      46.342408
# 1      52.211816      47.832878
# 2      51.645153      47.875014
# 3      52.834050      49.255452
# 4      54.641485      51.212763
# ...          ...            ...
# 3378   29.738298      32.509656
# 3379   29.841663      33.276570
# 3380   29.655293      33.074171
# 3381   29.628801      33.124907
# 3382   29.103382      32.476741
#
# [3383 rows x 6 columns]

# %%
df_pe = df['pe_ttm_avg', 'pe_ttm_ew', 'pe_ttm_ewpvo', 'pe_ttm_mcw', 'pe_ttm_median']
df_pe.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/inv_mgr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('pe_ttm_avg', 'pe_ttm_ew', 'pe_ttm_ewpvo', 'pe_ttm_mcw', 'pe_ttm_median')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-eaf24e63cd46> in <module>
# ----> 1 df_pe = df['pe_ttm_avg', 'pe_ttm_ew', 'pe_ttm_ewpvo', 'pe_ttm_mcw', 'pe_ttm_median']
#       2 df_pe.head()
#
# ~/opt/anaconda3/envs/inv_mgr/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/inv_mgr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: ('pe_ttm_avg', 'pe_ttm_ew', 'pe_ttm_ewpvo', 'pe_ttm_mcw', 'pe_ttm_median')
