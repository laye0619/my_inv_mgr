# %%
import xalpha as xa

# %%
cyb_index_info = xa.indexinfo('SZ399006')
cyb_fund_info = xa.fundinfo('159915')
cyb_fund_info.bcmkset(cyb_index_info, start='2018-01-01')
cyb_fund_info.v_netvalue()
# Out:
# 159915 赎回费信息异常，多是因为定开基金，封闭基金或场内 ETF: ['0.15%']
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="56ae42f0b65b48169129dfcf3c6749c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_56ae42f0b65b48169129dfcf3c6749c8 = echarts.init(
#                     document.getElementById('56ae42f0b65b48169129dfcf3c6749c8'), 'white', {renderer: 'canvas'});
#                 var option_56ae42f0b65b48169129dfcf3c6749c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %%
zz100_index_info = xa.indexinfo('SH000903')
zz100_fund_info = xa.fundinfo('512910')
zz100_fund_info.bcmkset(zz100_index_info, start='2018-01-01')
zz100_fund_info.v_netvalue()
# Out:
# 512910 赎回费信息异常，多是因为定开基金，封闭基金或场内 ETF: []
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f01310f44fce4946aab6bc29a87bf470" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f01310f44fce4946aab6bc29a87bf470 = echarts.init(
#                     document.getElementById('f01310f44fce4946aab6bc29a87bf470'), 'white', {renderer: 'canvas'});
#                 var option_f01310f44fce4946aab6bc29a87bf470 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...
