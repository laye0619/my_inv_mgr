# %%
import xalpha as xa
import pandas as pd

# %% [markdown]
# ### 养老产业指数与广发养老基金分析

# %%
yanglao_index = xa.indexinfo('SZ399812')
yanglao_fund = xa.fundinfo('000968')
yanglao_analysis = xa.evaluate(yanglao_fund, yanglao_index)
yanglao_analysis.v_netvalue()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3aa5f8172474407584ff45ff8a6b00fb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3aa5f8172474407584ff45ff8a6b00fb = echarts.init(
#                     document.getElementById('3aa5f8172474407584ff45ff8a6b00fb'), 'white', {renderer: 'canvas'});
#                 var option_3aa5f8172474407584ff45ff8a6b00fb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e7f\u53d1\u517b\u8001\u6307\u6570A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2015-02-13",
#                     1.0
#                 ],
#                 [
#                     "2015-02-17",
#                     1.0
#                 ],
#                 [
#                     "2015-02-27",
#                     1.0123
#                 ],
#                 [
#                     "2015-03-04",
#                     1.0426
#                 ],
#                 [
#                     "2015-03-05",
#                     1.0426
#                 ],
#                 [
#                     "2015-03-06",
#                     1.0183
#                 ],
#                 [
#                     "2015-03-09",
#                     1.0304
#                 ],
#                 [
#                     "2015-03-10",
#                     1.0403
#                 ],
#                 [
#                     "2015-03-11",
#                     1.0341
#                 ],
#                 [
#                     "2015-03-12",
#                     1.0334
#                 ],
#                 [
#                     "2015-03-13",
#                     1.046
#                 ],
#                 [
#                     "2015-03-16",
#                     1.0813
#                 ],
#                 [
#                     "2015-03-17",
#                     1.0818
#                 ],
#                 [
#                     "2015-03-18",
#                     1.1098
#                 ],
#                 [
#                     "2015-03-19",
#                     1.1066
#                 ],
#                 [
#                     "2015-03-20",
#                     1.1198
#                 ],
#                 [
#                     "2015-03-23",
#                     1.1537
#                 ],
#                 [
#                     "2015-03-24",
#                     1.1653
#                 ],
#                 [
#                     "2015-03-25",
#                     1.1708
#                 ],
#                 [
#                     "2015-03-26",
#                     1.1445
#                 ],
#                 [
#                     "2015-03-27",
#                     1.1519
#                 ],
#                 [
#                     "2015-03-30",
#                     1.1566
#                 ],
#                 [
#                     "2015-03-31",
#                     1.1584
#                 ],
#                 [
#                     "2015-04-01",
#                     1.1789
#                 ],
#                 [
#                     "2015-04-02",
#                     1.1923
#                 ],
#                 [
#                     "2015-04-03",
#                     1.2043
#                 ],
#                 [
#                     "2015-04-07",
#                     1.2251
#                 ],
#                 [
#                     "2015-04-08",
#                     1.1985
#                 ],
#                 [
#                     "2015-04-09",
#                     1.1869
#                 ],
#                 [
#                     "2015-04-10",
#                     1.2256
#                 ],
#                 [
#                     "2015-04-13",
#                     1.2514
#                 ],
#                 [
#                     "2015-04-14",
#                     1.2475
#                 ],
#                 [
#                     "2015-04-15",
#                     1.1991
#                 ],
#                 [
#                     "2015-04-16",
#                     1.2178
#                 ],
#                 [
#                     "2015-04-17",
#                     1.2145
#                 ],
#                 [
#                     "2015-04-20",
#                     1.1824
#                 ],
#                 [
#                     "2015-04-21",
#                     1.2347
#                 ],
#                 [
#                     "2015-04-22",
#                     1.2682
#                 ],
#                 [
#                     "2015-04-23",
#                     1.2778
#                 ],
#                 [
#                     "2015-04-24",
#                     1.2853
#                 ],
#                 [
#                     "2015-04-27",
#                     1.2926
#                 ],
#                 [
#                     "2015-04-28",
#                     1.2458
#                 ],
#                 [
#                     "2015-04-29",
#                     1.2777
#                 ],
#                 [
#                     "2015-04-30",
#                     1.2797
#                 ],
#                 [
#                     "2015-05-04",
#                     1.2771
#                 ],
#                 [
#                     "2015-05-05",
#                     1.2383
#                 ],
#                 [
#                     "2015-05-06",
#                     1.2433
#                 ],
#                 [
#                     "2015-05-07",
#                     1.23
#                 ],
#                 [
#                     "2015-05-08",
#                     1.2783
#                 ],
#                 [
#                     "2015-05-11",
#                     1.3331
#                 ],
#                 [
#                     "2015-05-12",
#                     1.3592
#                 ],
#                 [
#                     "2015-05-13",
#                     1.3777
#                 ],
#                 [
#                     "2015-05-14",
#                     1.3716
#                 ],
#                 [
#                     "2015-05-15",
#                     1.3629
#                 ],
#                 [
#                     "2015-05-18",
#                     1.3811
#                 ],
#                 [
#                     "2015-05-19",
#                     1.415
#                 ],
#                 [
#                     "2015-05-20",
#                     1.4352
#                 ],
#                 [
#                     "2015-05-21",
#                     1.4835
#                 ],
#                 [
#                     "2015-05-22",
#                     1.4891
#                 ],
#                 [
#                     "2015-05-25",
#                     1.5149
#                 ],
#                 [
#                     "2015-05-26",
#                     1.5574
#                 ],
#                 [
#                     "2015-05-27",
#                     1.5631
#                 ],
#                 [
#                     "2015-05-28",
#                     1.4742
#                 ],
#                 [
#                     "2015-05-29",
#                     1.4972
#                 ],
#                 [
#                     "2015-06-01",
#                     1.5756
#                 ],
#                 [
#                     "2015-06-02",

# %%
yanglao_fund.which_industry()
# Out:
# '行业基金： 医药生物'

# %% [markdown]
# ### 28轮动相关研究

# %%
zz100 = xa.indexinfo('SH000903')
cyb = xa.indexinfo('SZ399006')
zz500 = xa.indexinfo('SH000905')
hs300 = xa.indexinfo('SH000300')
t28_analysis = xa.evaluate(zz100, cyb, zz500, hs300)
t28_analysis.v_correlation()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0482c18c1cf94d76b73732f734d8338d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0482c18c1cf94d76b73732f734d8338d = echarts.init(
#                     document.getElementById('0482c18c1cf94d76b73732f734d8338d'), 'white', {renderer: 'canvas'});
#                 var option_0482c18c1cf94d76b73732f734d8338d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u76f8\u5173\u6027",
#             "data": [
#                 [
#                     0,
#                     0,
#                     1.0
#                 ],
#                 [
#                     0,
#                     1,
#                     0.5876630660496084
#                 ],
#                 [
#                     0,
#                     2,
#                     0.7440946730304671
#                 ],
#                 [
#                     0,
#                     3,
#                     0.9785172188824957
#                 ],
#                 [
#                     1,
#                     0,
#                     0.5876630660496084
#                 ],
#                 [
#                     1,
#                     1,
#                     1.0
#                 ],
#                 [
#                     1,
#                     2,
#                     0.8883285117848325
#                 ],
#                 [
#                     1,
#                     3,
#                     0.7120718342672607
#                 ],
#                 [
#                     2,
#                     0,
#                     0.7440946730304671
#                 ],
#                 [
#                     2,
#                     1,
#                     0.8883285117848325
#                 ],
#                 [
#                     2,
#                     2,
#                     1.0
#                 ],
#                 [
#                     2,
#                     3,
#                     0.8570633514033756
#                 ],
#                 [
#                     3,
#                     0,
#                     0.9785172188824957
#                 ],
#                 [
#                     3,
#                     1,
#                     0.7120718342672607
#                 ],
#                 [
#                     3,
#                     2,
#                     0.8570633514033756
#                 ],
#                 [
#                     3,
#                     3,
#                     1.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f8\u5173\u6027"
#             ],
#             "selected": {
#                 "\u76f8\u5173\u6027": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0000903",
#                 "1399006",
#                 "0000905",
#                 "0000300"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0000903",
#                 "1399006",
#                 "0000905",
#                 "0000300"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": -1,
#         "max": 1,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "horizontal",
#         "top": "bottom",
#         "right": "middle",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_0482c18c1cf94d76b73732f734d8338d.setOption(option_0482c18c1cf94d76b73732f734d8338d);
#         });
#     </script>

# %%
cyb_etf = xa.fundinfo('159915', dividend_label=1)
ccz_etf = xa.fundinfo('159967', dividend_label=1)
cyb_etf_analysis = xa.evaluate(cyb_etf, ccz_etf,start=pd.to_datetime('20200101'))
cyb_etf_analysis.v_netvalue()
# Out:
# 159915 赎回费信息异常，多是因为定开基金，封闭基金或场内 ETF: ['0.15%']
# 159967 赎回费信息异常，多是因为定开基金，封闭基金或场内 ETF: []
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3669a74d28fb45e199023e6cfa10ccfc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3669a74d28fb45e199023e6cfa10ccfc = echarts.init(
#                     document.getElementById('3669a74d28fb45e199023e6cfa10ccfc'), 'white', {renderer: 'canvas'});
#                 var option_3669a74d28fb45e199023e6cfa10ccfc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6613\u65b9\u8fbe\u521b\u4e1a\u677fETF",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2021-01-04",
#                     1.0
#                 ],
#                 [
#                     "2021-01-05",
#                     1.0063887020847342
#                 ],
#                 [
#                     "2021-01-06",
#                     1.0119367854741088
#                 ],
#                 [
#                     "2021-01-07",
#                     1.0272696704774713
#                 ],
#                 [
#                     "2021-01-08",
#                     1.0234700739744451
#                 ],
#                 [
#                     "2021-01-11",
#                     1.004640215198386
#                 ],
#                 [
#                     "2021-01-12",
#                     1.0330195023537323
#                 ],
#                 [
#                     "2021-01-13",
#                     1.0167451244115668
#                 ],
#                 [
#                     "2021-01-14",
#                     1.0033960995292535
#                 ],
#                 [
#                     "2021-01-15",
#                     1.0036650975117687
#                 ],
#                 [
#                     "2021-01-18",
#                     1.0227975790181572
#                 ],
#                 [
#                     "2021-01-19",
#                     1.001815736381977
#                 ],
#                 [
#                     "2021-01-20",
#                     1.0408540685944854
#                 ],
#                 [
#                     "2021-01-21",
#                     1.0663416274377941
#                 ],
#                 [
#                     "2021-01-22",
#                     1.0904841963685272
#                 ],
#                 [
#                     "2021-01-25",
#                     1.0894754539340954
#                 ],
#                 [
#                     "2021-01-26",
#                     1.0580363147276395
#                 ],
#                 [
#                     "2021-01-27",
#                     1.0653665097511769
#                 ],
#                 [
#                     "2021-01-28",
#                     1.026731674512441
#                 ],
#                 [
#                     "2021-01-29",
#                     1.0160053799596502
#                 ],
#                 [
#                     "2021-02-01",
#                     1.0260591795561531
#                 ],
#                 [
#                     "2021-02-02",
#                     1.0483187626092805
#                 ],
#                 [
#                     "2021-02-03",
#                     1.0467047747141895
#                 ],
#                 [
#                     "2021-02-04",
#                     1.0391728312037658
#                 ],
#                 [
#                     "2021-02-05",
#                     1.0369199731002017
#                 ],
#                 [
#                     "2021-02-08",
#                     1.064189643577673
#                 ],
#                 [
#                     "2021-02-09",
#                     1.0824142568930732
#                 ],
#                 [
#                     "2021-02-10",
#                     1.108170813718897
#                 ],
#                 [
#                     "2021-02-18",
#                     1.077673167451244
#                 ],
#                 [
#                     "2021-02-19",
#                     1.0664425016812373
#                 ],
#                 [
#                     "2021-02-22",
#                     1.0187962340282448
#                 ],
#                 [
#                     "2021-02-23",
#                     1.0102891728312038
#                 ],
#                 [
#                     "2021-02-24",
#                     0.9762609280430397
#                 ],
#                 [
#                     "2021-02-25",
#                     0.9664761264290517
#                 ],
#                 [
#                     "2021-02-26",
#                     0.9460659045057161
#                 ],
#                 [
#                     "2021-03-01",
#                     0.9721250840618694
#                 ],
#                 [
#                     "2021-03-02",
#                     0.9630800268997981
#                 ],
#                 [
#                     "2021-03-03",
#                     0.9730665770006725
#                 ],
#                 [
#                     "2021-03-04",
#                     0.9257901815736381
#                 ],
#                 [
#                     "2021-03-05",
#                     0.93231338264963
#                 ],
#                 [
#                     "2021-03-08",
#                     0.8859112306657699
#                 ],
#                 [
#                     "2021-03-09",
#                     0.8549428379287155
#                 ],
#                 [
#                     "2021-03-10",
#                     0.8689643577673166
#                 ],
#                 [
#                     "2021-03-11",
#                     0.8915938130464022
#                 ],
#                 [
#                     "2021-03-12",
#                     0.8949226630800269
#                 ],
#                 [
#                     "2021-03-15",
#                     0.8583053127101546
#                 ],
#                 [
#                     "2021-03-16",
#                     0.8674176193678547
#                 ],
#                 [
#                     "2021-03-17",
#                     0.8777740416946872
#                 ],
#                 [
#                     "2021-03-18",
#                     0.8922326832548756
#                 ],
#                 [
#                     "2021-03-19",
#                     0.8672158708809683
#                 ],
#                 [
#                     "2021-03-22",
#                     0.875857431069267
#                 ],
#                 [
#                     "2021-03-23",
#                     0.866072629455279
#                 ],
#                 [
#                     "2021-03-24",
#                     0.8552118359112306
#                 ],
#                 [
#                     "2021-03-25",
#                     0.8621721587088096
#                 ],
#                 [
#                     "2021-03-26",
#                     0.8911230665770006
#                 ],
#                 [
#                     "2021-03-29",
#                     0.8874243443174177
#                 ],
#                 [
#                     "2021-03-30",
#                     0.8994956287827841
#                 ],
#                 [
#                     "2021-03-31",
#                     0.8954942837928714
#                 ],
#                 [
#                     "2021-04-01",

# %%
ccz_etf.price
# Out:
#           date  netvalue  comment  totvalue
# 0   2019-06-21    1.0260      0.0    1.0260
# 1   2019-06-28    1.0276      0.0    1.0276
# 2   2019-07-05    1.0364      0.0    1.0364
# 3   2019-07-08    1.0289      0.0    1.0289
# 4   2019-07-12    1.0320      0.0    1.0320
# ..         ...       ...      ...       ...
# 431 2021-04-15    0.6207      0.0    2.2583
# 432 2021-04-16    0.6161      0.0    2.2416
# 433 2021-04-19    0.6413      0.0    2.3333
# 434 2021-04-20    0.6444      0.0    2.3446
# 435 2021-04-21    0.6504      0.0    2.3664
#
# [436 rows x 4 columns]
